# %%
import pickle

file_path ="/home/tommy/Project/PCBSDA/ours/outputs/embedded_graphs/cbow/17/17a4d5b603e622543b10d2b2b3a03cc38fdc170db45b8edd44e83973a39c71db.gpickle"

with open(file_path, 'rb') as f:
    data = pickle.load(f)


print(data)

for node in data.nodes(data=True):
    print(node)
# Out:
# DiGraph with 250 nodes and 560 edges
# ('0x8048094', {'x': array([-1.0487983e+00,  2.1410683e-01,  9.5441014e-01,  1.1492320e+00,
#        -5.6120414e-01, -3.9109552e-01,  1.2156223e+00,  1.5687678e+00,
#         6.2104130e-01, -6.2741536e-01, -4.2533180e-01, -5.9736913e-01,
#         1.2270035e+00,  5.1249653e-01, -1.0088803e+00,  1.8293199e-01,
#         1.9824627e-01,  2.4838036e-01, -3.6059347e-01, -4.0237641e-01,
#        -1.5261598e-01,  2.0839348e+00, -1.7826240e-01,  8.2375604e-01,
#         2.3281384e+00, -2.6618630e-01, -5.4406595e-01, -1.6273030e+00,
#        -1.1427077e+00,  5.6884921e-01,  5.9025800e-01, -2.9312465e-01,
#         1.0371087e+00, -6.3428503e-01,  1.6717283e-01,  1.9594897e-01,
#        -7.3192167e-01, -6.2562108e-01,  4.2023501e-01, -2.5747684e-01,
#         8.9406097e-01,  3.2838342e-01, -6.3652432e-01, -6.6842347e-01,
#         3.0244499e-01, -1.7974538e-01,  4.0223747e-01,  7.4406850e-01,
# ...

# %%
import pickle

file_path = "/home/tommy/Project/PCBSDA/ours/outputs/raw_data/gnn/gpickle/00/00a4f75fdbf16f9e4bf7044374a92ec207648470d32fd8680a26e5c832108cd8.gpickle"

with open(file_path, "rb") as f:
    data = pickle.load(f)
    
for node in data.nodes(data=True):
    print(node)

for edge in data.edges(data=True):   
    print(edge)
# Out:
# ('0x10000094', {'function_name': 'FUN_10000094', 'tokens': ['CALL', 'CALL', 'RETURN']})
# ('0x100000b8', {'function_name': 'FUN_100000b8', 'tokens': ['INT_EQUAL', 'CBRANCH', 'LOAD', 'CAST', 'INT_NOTEQUAL', 'COPY', 'CBRANCH', 'MULTIEQUAL', 'MULTIEQUAL', 'MULTIEQUAL', 'PTRADD', 'CALLIND', 'INDIRECT', 'INDIRECT', 'LOAD', 'CAST', 'COPY', 'MULTIEQUAL', 'MULTIEQUAL', 'RETURN', 'COPY', 'COPY']})
# ('0x10000168', {'function_name': 'FUN_10000168', 'tokens': ['RETURN', 'PTRSUB', 'COPY']})
# ('0x100001f0', {'function_name': 'entry', 'tokens': ['PTRSUB', 'CALL', 'RETURN', 'PTRSUB', 'PTRSUB']})
# ...
